# %% [markdown]
#  # Step 1: Loading and Schema Validation

# %%
import polars as pl 

data  = pl.read_csv('/home/brahimaskiou/Documents/jobsim/quantium/Data/QVI_purchase_behaviour.csv')
print(data )

# %%
print("hh")
